# %% [markdown]
# **Image** **Resources** **and** **Display** **Image**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
picture = '/content/gdrive/My Drive/gigi/max.jpg'

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import cv2
import numpy as np

# %matplotlib inline

# Read in the image
image = mpimg.imread(picture)


#plt.axis('off')

plt.imshow(image)

# %% [markdown]
# **Convert image to grayscale**

# %%
# Convert to grayscale for filtering
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray, cmap='gray')

# %% [markdown]
# **Apply the Sobel Operator**

# %%
# 3x3 array for edge detection
sobel_y = np.array([[ 0, 0, 0], 
                   [ 0, 0, 0], 
                   [ 0, 2, 0]])


# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)  
filtered_image = cv2.filter2D(gray, -1, sobel_y)

plt.imshow(filtered_image, cmap='gray')

# %%
# Create a custom kernel

# 3x3 array for edge detection
sobel_y = np.array([[ 0, 0, 0], 
                   [ 0, 0, 0], 
                   [ 1, 2, 0]])

## TODO: Create and apply a Sobel x operator
sobel_x = np.array([[ -1, -2, -1],
                   [0, 0, 0],
                   [1, 2, 1]])


sobel_z = np.concatenate((sobel_y,sobel_x),axis=1)


# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)  
filtered_image = cv2.filter2D(gray, -1, sobel_z)

plt.imshow(filtered_image, cmap='gray')
